# %% [markdown]
# # Die Stimmungserkennung (SER)

# %% [markdown]
# ## Inhalt
#
# * [Tensorboard](#Tensorboard)
# * [Python-Bibliotheken](#Bibliotheken)
# * [Die Vorverarbeitung](#Vorverarbeitung)
#     * [Die Datenbeladung](#Datenbeladung)
#     * [Die Datenvisualisierung](#datenvisual)
# * [Das Klassifikationsmodell](#klassifikationsmodell)
#     * [Die Modellskonfiguration](#modelskonfiguration)
#     * [Die Modellstruktur](#modellstruktur)
#     * [Modell-Training](#modelltraining)
# * [Save Modell](#savemodell)
# * [Test Modell](#testmodell)
#     * [Die Ganauigkeit](#ganauigkeit)
#     * [Die Metriken](#metriken)

# %% [markdown]
# ## Tensorboard<a class="anchor" id="Tensorboard"></a>

# %% [markdown]
# #### Tensorboard ist eine Webanwendung zur Visualisierungverschidener Aspekte neuronaler Netze

# %%
from keras.backend import clear_session
clear_session()
# %reload_ext tensorboard

# %% [markdown]
# ## Python-Bibliotheken<a class="anchor" id="Bibliotheken"></a>

# %%
import torch
import keras
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import random
import pandas as pd
import tensorflow as tf
from torchvision import models, transforms
from pathlib import Path
from torch.utils.data import Dataset, DataLoader
import torchvision
from functools import partial
import keras
import itertools
from tensorflow.keras.losses import sparse_categorical_crossentropy
from tensorflow.keras.optimizers import Adam
from PIL import Image
from sklearn.metrics import classification_report,confusion_matrix

# %% [markdown]
# ## Die Vorverarbeitung<a class="anchor" id="Vorverarbeitung"></a>

# %%
# "surprise" wird von 8 auf 0 geändert
EMOTIONS = {1:'neutral', 2:'calm', 3:'happy', 4:'sad', 5:'angry', 6:'fear', 7:'disgust', 0:'surprise'}

# %%
# Audiodateien
PATH_TO_RAVDESS = Path.cwd()/"ravdess"
PATH_RAVDESS_TRAIN = PATH_TO_RAVDESS/"train"
bs_train = 1440

# %%
# Confusion Matrix
class_names = [EMOTIONS[ind] for ind in range(len(EMOTIONS))]
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
  #      cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

 #   print(cm)
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")


    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %% [markdown]
# ### Die Datenbeladung<a class="anchor" id="Datenbeladung"></a>

# %%
class PrecomputedRavdess(Dataset):
    def __init__(self,path,dpi=50, img_transforms=None):
        files = Path(path).glob('{}{}*.wav.png'.format(path.name, dpi))
        self.items = [(f,int(f.name.split("-")[2].replace(".wav.png",""))) for f in files]
        self.length = len(self.items)
        if img_transforms == None:
            self.img_transforms = transforms.Compose([transforms.ToTensor()])
        else:
            self.img_transforms = img_transforms
    
    def __getitem__(self, index):
        
        filename, label = self.items[index]
        img = Image.open(filename).convert('RGB')
        return (self.img_transforms(img), label)
            
    def __len__(self):
        return self.length

# %%
def loader(path):
    ravdess = PrecomputedRavdess(path,
                                  img_transforms=transforms.Compose([
                                     transforms.ToTensor(),
                                     transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                                          std=[0.229, 0.224, 0.225])])
    )
    return ravdess

# %%
ravdess_train = loader(PATH_RAVDESS_TRAIN)
ravdess_train_loader = torch.utils.data.DataLoader(ravdess_train,bs_train, shuffle=True)
spectogram = torch.utils.data.DataLoader(ravdess_train,64,shuffle=True )

# %% [markdown]
# ### Die Datenvisualisierung<a class="anchor" id="#datenvisual"></a>

# %%
images, labels = next(iter(ravdess_train_loader))  
img, label = next(iter(spectogram))  
def imshow(img):
     img = img / 2 + 0.5
     npimg = img.numpy()
     plt.imshow(np.transpose(npimg, (1, 2, 0)))
     plt.show()
print('Validationslabel:',label)
imshow(torchvision.utils.make_grid(img)/3)
# Out:
# Validationslabel: tensor([4, 7, 3, 7, 6, 1, 0, 2, 7, 0, 3, 6, 0, 6, 0, 2, 0, 5, 0, 3, 0, 7, 7, 4,
#         2, 2, 6, 5, 1, 1, 2, 7, 4, 3, 1, 7, 1, 6, 2, 0, 7, 7, 3, 7, 6, 1, 6, 2,
#         4, 1, 4, 3, 7, 2, 4, 7, 6, 5, 6, 3, 3, 5, 4, 7])

# %%
labels.shape
# Out:
# torch.Size([1161])

# %% [markdown]
# ## Das Klassifikationsmodell<a class="anchor" id="#klassifikationsmodell"></a>

# %% [markdown]
# ### Die Modellskonfiguration<a class="anchor" id="#modelskonfiguration"></a>

# %%
batch_size = 64
img_width, img_height, img_num_channels = 3,200,300
loss_function = sparse_categorical_crossentropy
no_classes = 8
optimizer = Adam()
verbosity = 1
input_shape = (img_width, img_height, img_num_channels)

# %%
# Residual Unit-Schicht
# Im Konstruktor werden alle erforderlichen Schichten erzeugt
DefaultConv2D = partial(keras.layers.Conv2D, kernel_size=3, strides=1,
                        padding="SAME", use_bias=False)

class ResidualUnit(keras.layers.Layer):
    def __init__(self, filters, strides=1, activation="relu", **kwargs):
        super().__init__(**kwargs)
        self.activation = keras.activations.get(activation)
        self.main_layers = [
            DefaultConv2D(filters, strides=strides),
            keras.layers.BatchNormalization(),
            self.activation,
            DefaultConv2D(filters),
            keras.layers.BatchNormalization()]
        self.skip_layers = []
        if strides > 1:
            self.skip_layers = [
                DefaultConv2D(filters, kernel_size=1, strides=strides),
                keras.layers.BatchNormalization()]

    def call(self, inputs):
        Z = inputs
        for layer in self.main_layers:
            Z = layer(Z)
        skip_Z = inputs
        for layer in self.skip_layers:
            skip_Z = layer(skip_Z)
        return self.activation(Z + skip_Z)

# %%
#Das ResNet-34 kann mit einem Sequential-Modell angebaut werden.
def build_model():
    model = keras.models.Sequential()
    model.add(DefaultConv2D(64, kernel_size=3, strides=1,
                        input_shape= input_shape ))
    model.add(keras.layers.BatchNormalization())
    model.add(keras.layers.Activation("relu"))
    model.add(keras.layers.MaxPool2D(pool_size=3, strides=2, padding="SAME"))
    prev_filters = 8
    for filters in [64] * 1 + [128] * 1 + [256] * 1: 
        strides = 1 if filters == prev_filters else 2
        model.add(ResidualUnit(filters, strides=strides))
        prev_filters = filters
    model.add(keras.layers.GlobalAvgPool2D())
    model.add(keras.layers.Flatten())
    model.add(keras.layers.Dense(no_classes, activation="softmax"))
    optimizer = keras.optimizers.Nadam(lr=1e-3)
    model.compile(loss=loss_function,
              optimizer=optimizer,  metrics=['accuracy'])
    return model

# %%
# Datentyp-Umwandelung
images = (tf.cast(images, tf.float32) / 255).numpy()
labels = labels.numpy()

# %% [markdown]
# ### Die Modellstruktur<a class="anchor" id="#modellstruktur"></a>

# %%
model = build_model()
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_10 (Conv2D)           (None, 3, 200, 64)        172800
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 3, 200, 64)        256
# _________________________________________________________________
# activation_1 (Activation)    (None, 3, 200, 64)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 2, 100, 64)        0
# _________________________________________________________________
# residual_unit_3 (ResidualUni (None, 1, 50, 64)         78592
# _________________________________________________________________
# residual_unit_4 (ResidualUni (None, 1, 25, 128)        230912
# _________________________________________________________________
# residual_unit_5 (ResidualUni (None, 1, 13, 256)        920576
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 256)               0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 8)                 2056
# =================================================================
# Total params: 1,405,192
# Trainable params: 1,402,376
# Non-trainable params: 2,816
# _________________________________________________________________

# %% [markdown]
# ### Modell-Training<a class="anchor" id="#modelltraining"></a>

# %%
history = model.fit(images, labels,
            batch_size=batch_size,
            epochs=100,        
            verbose=verbosity,
            validation_split = 0.2)
# Out:
# Epoch 1/100
# 15/15 [==============================] - 10s 489ms/step - loss: 2.1075 - accuracy: 0.2101 - val_loss: 2.0744 - val_accuracy: 0.1373
# Epoch 2/100
# 15/15 [==============================] - 7s 466ms/step - loss: 1.6340 - accuracy: 0.3855 - val_loss: 2.0856 - val_accuracy: 0.1373
# Epoch 3/100
# 15/15 [==============================] - 7s 468ms/step - loss: 1.3657 - accuracy: 0.4967 - val_loss: 2.1351 - val_accuracy: 0.1373
# Epoch 4/100
# 15/15 [==============================] - 7s 465ms/step - loss: 1.1656 - accuracy: 0.5800 - val_loss: 2.2398 - val_accuracy: 0.1373
# Epoch 5/100
# 15/15 [==============================] - 7s 472ms/step - loss: 1.0363 - accuracy: 0.6417 - val_loss: 2.3246 - val_accuracy: 0.1373
# Epoch 6/100
# 15/15 [==============================] - 8s 503ms/step - loss: 0.7629 - accuracy: 0.7476 - val_loss: 2.5319 - val_accuracy: 0.1373
# Epoch 7/100
# 15/15 [==============================] - 7s 467ms/step - loss: 0.6103 - accuracy: 0.7901 - val_loss: 2.7943 - val_accuracy: 0.1373
# Epoch 8/100
# 15/15 [==============================] - 7s 470ms/step - loss: 0.4656 - accuracy: 0.8484 - val_loss: 2.8246 - val_accuracy: 0.1373
# Epoch 9/100
# 15/15 [==============================] - 7s 467ms/step - loss: 0.3896 - accuracy: 0.8785 - val_loss: 3.3712 - val_accuracy: 0.1373
# Epoch 10/100
# 15/15 [==============================] - 7s 470ms/step - loss: 0.3550 - accuracy: 0.8916 - val_loss: 3.0515 - val_accuracy: 0.1373
# Epoch 11/100
# 15/15 [==============================] - 7s 470ms/step - loss: 0.1418 - accuracy: 0.9751 - val_loss: 3.2570 - val_accuracy: 0.1373
# Epoch 12/100
# 15/15 [==============================] - 7s 470ms/step - loss: 0.0897 - accuracy: 0.9938 - val_loss: 3.6922 - val_accuracy: 0.1030
# Epoch 13/100
# 15/15 [==============================] - 7s 472ms/step - loss: 0.0637 - accuracy: 0.9899 - val_loss: 4.7945 - val_accuracy: 0.1030
# Epoch 14/100
# 15/15 [==============================] - 7s 468ms/step - loss: 0.0449 - accuracy: 0.9940 - val_loss: 5.4353 - val_accuracy: 0.1030
# Epoch 15/100
# 15/15 [==============================] - 7s 485ms/step - loss: 0.0169 - accuracy: 1.0000 - val_loss: 6.4780 - val_accuracy: 0.1030
# Epoch 16/100
# 15/15 [==============================] - 7s 472ms/step - loss: 0.0111 - accuracy: 1.0000 - val_loss: 7.8243 - val_accuracy: 0.1030
# Epoch 17/100
# 15/15 [==============================] - 7s 470ms/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 9.2881 - val_accuracy: 0.1030
# Epoch 18/100
# 15/15 [==============================] - 7s 485ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 10.5215 - val_accuracy: 0.1030
# Epoch 19/100
# 15/15 [==============================] - 8s 503ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 11.6210 - val_accuracy: 0.1030
# Epoch 20/100
# 15/15 [==============================] - 7s 480ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 12.7750 - val_accuracy: 0.1030
# Epoch 21/100
# 15/15 [==============================] - 7s 485ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 13.9635 - val_accuracy: 0.1030
# Epoch 22/100
# 15/15 [==============================] - 7s 489ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 15.4644 - val_accuracy: 0.1030
# Epoch 23/100
# 15/15 [==============================] - 7s 489ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 16.6986 - val_accuracy: 0.1030
# Epoch 24/100
# 15/15 [==============================] - 7s 491ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 17.9130 - val_accuracy: 0.1030
# Epoch 25/100
# 15/15 [==============================] - 7s 494ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 18.7680 - val_accuracy: 0.1030
# Epoch 26/100
# 15/15 [==============================] - 7s 494ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 19.4212 - val_accuracy: 0.1030
# Epoch 27/100
# 15/15 [==============================] - 7s 495ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 20.1344 - val_accuracy: 0.1030
# Epoch 28/100
# 15/15 [==============================] - 7s 478ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 20.6522 - val_accuracy: 0.1030
# Epoch 29/100
# 15/15 [==============================] - 7s 467ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 20.7273 - val_accuracy: 0.1030
# Epoch 30/100
# 15/15 [==============================] - 7s 473ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 20.6798 - val_accuracy: 0.1030
# Epoch 31/100
# 15/15 [==============================] - 7s 467ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 20.0772 - val_accuracy: 0.1030
# Epoch 32/100
# 15/15 [==============================] - 7s 466ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 19.5842 - val_accuracy: 0.1030
# Epoch 33/100
# 15/15 [==============================] - 7s 467ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 18.8081 - val_accuracy: 0.1030
# Epoch 34/100
# 15/15 [==============================] - 7s 469ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 17.9869 - val_accuracy: 0.1030
# Epoch 35/100
# 15/15 [==============================] - 7s 471ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 16.9501 - val_accuracy: 0.1073
# Epoch 36/100
# 15/15 [==============================] - 7s 467ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 16.2179 - val_accuracy: 0.1288
# Epoch 37/100
# 15/15 [==============================] - 7s 467ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 15.1348 - val_accuracy: 0.1373
# Epoch 38/100
# 15/15 [==============================] - 7s 468ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 13.9087 - val_accuracy: 0.1545
# Epoch 39/100
# 15/15 [==============================] - 7s 466ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 12.8649 - val_accuracy: 0.1545
# Epoch 40/100
# 15/15 [==============================] - 7s 468ms/step - loss: 9.9600e-04 - accuracy: 1.0000 - val_loss: 12.1463 - val_accuracy: 0.1545
# Epoch 41/100
# 15/15 [==============================] - 7s 466ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 11.3639 - val_accuracy: 0.1545
# Epoch 42/100
# 15/15 [==============================] - 7s 466ms/step - loss: 9.8659e-04 - accuracy: 1.0000 - val_loss: 9.7706 - val_accuracy: 0.1674
# Epoch 43/100
# 15/15 [==============================] - 7s 468ms/step - loss: 9.4414e-04 - accuracy: 1.0000 - val_loss: 8.2538 - val_accuracy: 0.1760
# Epoch 44/100
# 15/15 [==============================] - 7s 468ms/step - loss: 8.7405e-04 - accuracy: 1.0000 - val_loss: 7.3662 - val_accuracy: 0.1888
# Epoch 45/100
# 15/15 [==============================] - 7s 467ms/step - loss: 7.6579e-04 - accuracy: 1.0000 - val_loss: 5.7992 - val_accuracy: 0.2833
# Epoch 46/100
# 15/15 [==============================] - 7s 467ms/step - loss: 8.9273e-04 - accuracy: 1.0000 - val_loss: 4.9299 - val_accuracy: 0.2961
# Epoch 47/100
# 15/15 [==============================] - 7s 471ms/step - loss: 7.0119e-04 - accuracy: 1.0000 - val_loss: 4.2680 - val_accuracy: 0.3047
# Epoch 48/100
# 15/15 [==============================] - 7s 467ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 3.4552 - val_accuracy: 0.3948
# Epoch 49/100
# 15/15 [==============================] - 7s 466ms/step - loss: 6.0263e-04 - accuracy: 1.0000 - val_loss: 2.9626 - val_accuracy: 0.4421
# Epoch 50/100
# 15/15 [==============================] - 7s 467ms/step - loss: 6.6571e-04 - accuracy: 1.0000 - val_loss: 2.6495 - val_accuracy: 0.4678
# Epoch 51/100
# 15/15 [==============================] - 7s 466ms/step - loss: 7.2684e-04 - accuracy: 1.0000 - val_loss: 2.3612 - val_accuracy: 0.5064
# Epoch 52/100
# 15/15 [==============================] - 7s 467ms/step - loss: 7.5055e-04 - accuracy: 1.0000 - val_loss: 2.2303 - val_accuracy: 0.5322
# Epoch 53/100
# 15/15 [==============================] - 7s 467ms/step - loss: 5.5283e-04 - accuracy: 1.0000 - val_loss: 1.9823 - val_accuracy: 0.5622
# Epoch 54/100
# 15/15 [==============================] - 7s 465ms/step - loss: 5.5270e-04 - accuracy: 1.0000 - val_loss: 1.8484 - val_accuracy: 0.5665
# Epoch 55/100
# 15/15 [==============================] - 7s 468ms/step - loss: 5.6962e-04 - accuracy: 1.0000 - val_loss: 1.7432 - val_accuracy: 0.5837
# Epoch 56/100
# 15/15 [==============================] - 7s 466ms/step - loss: 5.5497e-04 - accuracy: 1.0000 - val_loss: 1.5982 - val_accuracy: 0.6052
# Epoch 57/100
# 15/15 [==============================] - 7s 466ms/step - loss: 5.2119e-04 - accuracy: 1.0000 - val_loss: 1.5638 - val_accuracy: 0.6094
# Epoch 58/100
# 15/15 [==============================] - 7s 466ms/step - loss: 5.3025e-04 - accuracy: 1.0000 - val_loss: 1.5160 - val_accuracy: 0.6223
# Epoch 59/100
# 15/15 [==============================] - 7s 466ms/step - loss: 4.9247e-04 - accuracy: 1.0000 - val_loss: 1.5356 - val_accuracy: 0.6266
# Epoch 60/100
# 15/15 [==============================] - 7s 467ms/step - loss: 5.0557e-04 - accuracy: 1.0000 - val_loss: 1.4881 - val_accuracy: 0.6395
# Epoch 61/100
# 15/15 [==============================] - 7s 468ms/step - loss: 4.0280e-04 - accuracy: 1.0000 - val_loss: 1.4505 - val_accuracy: 0.6266
# Epoch 62/100
# 15/15 [==============================] - 7s 464ms/step - loss: 4.2216e-04 - accuracy: 1.0000 - val_loss: 1.4341 - val_accuracy: 0.6352
# Epoch 63/100
# 15/15 [==============================] - 7s 473ms/step - loss: 4.7358e-04 - accuracy: 1.0000 - val_loss: 1.4127 - val_accuracy: 0.6438
# Epoch 64/100
# 15/15 [==============================] - 7s 476ms/step - loss: 5.5266e-04 - accuracy: 1.0000 - val_loss: 1.4018 - val_accuracy: 0.6352
# Epoch 65/100
# 15/15 [==============================] - 7s 467ms/step - loss: 3.1596e-04 - accuracy: 1.0000 - val_loss: 1.3761 - val_accuracy: 0.6438
# Epoch 66/100
# 15/15 [==============================] - 7s 466ms/step - loss: 4.1942e-04 - accuracy: 1.0000 - val_loss: 1.3683 - val_accuracy: 0.6438
# Epoch 67/100
# 15/15 [==============================] - 7s 465ms/step - loss: 5.0203e-04 - accuracy: 1.0000 - val_loss: 1.3653 - val_accuracy: 0.6524
# Epoch 68/100
# 15/15 [==============================] - 7s 466ms/step - loss: 3.6797e-04 - accuracy: 1.0000 - val_loss: 1.3475 - val_accuracy: 0.6524
# Epoch 69/100
# 15/15 [==============================] - 7s 468ms/step - loss: 3.6908e-04 - accuracy: 1.0000 - val_loss: 1.3562 - val_accuracy: 0.6395
# Epoch 70/100
# 15/15 [==============================] - 7s 469ms/step - loss: 3.2023e-04 - accuracy: 1.0000 - val_loss: 1.3515 - val_accuracy: 0.6352
# Epoch 71/100
# 15/15 [==============================] - 7s 466ms/step - loss: 3.3441e-04 - accuracy: 1.0000 - val_loss: 1.3670 - val_accuracy: 0.6438
# Epoch 72/100
# 15/15 [==============================] - 7s 477ms/step - loss: 3.2679e-04 - accuracy: 1.0000 - val_loss: 1.3733 - val_accuracy: 0.6567
# Epoch 73/100
# 15/15 [==============================] - 7s 474ms/step - loss: 4.0218e-04 - accuracy: 1.0000 - val_loss: 1.3586 - val_accuracy: 0.6567
# Epoch 74/100
# 15/15 [==============================] - 7s 466ms/step - loss: 3.0335e-04 - accuracy: 1.0000 - val_loss: 1.3597 - val_accuracy: 0.6524
# Epoch 75/100
# 15/15 [==============================] - 7s 465ms/step - loss: 2.5839e-04 - accuracy: 1.0000 - val_loss: 1.3931 - val_accuracy: 0.6524
# Epoch 76/100
# 15/15 [==============================] - 7s 466ms/step - loss: 2.8468e-04 - accuracy: 1.0000 - val_loss: 1.3833 - val_accuracy: 0.6567
# Epoch 77/100
# 15/15 [==============================] - 7s 470ms/step - loss: 3.0691e-04 - accuracy: 1.0000 - val_loss: 1.3616 - val_accuracy: 0.6481
# Epoch 78/100
# 15/15 [==============================] - 7s 468ms/step - loss: 2.7211e-04 - accuracy: 1.0000 - val_loss: 1.3575 - val_accuracy: 0.6481
# Epoch 79/100
# 15/15 [==============================] - 7s 466ms/step - loss: 2.5382e-04 - accuracy: 1.0000 - val_loss: 1.3511 - val_accuracy: 0.6524
# Epoch 80/100
# 15/15 [==============================] - 7s 465ms/step - loss: 3.0476e-04 - accuracy: 1.0000 - val_loss: 1.3461 - val_accuracy: 0.6524
# Epoch 81/100
# 15/15 [==============================] - 7s 473ms/step - loss: 2.7798e-04 - accuracy: 1.0000 - val_loss: 1.3568 - val_accuracy: 0.6567
# Epoch 82/100
# 15/15 [==============================] - 7s 466ms/step - loss: 2.8720e-04 - accuracy: 1.0000 - val_loss: 1.3772 - val_accuracy: 0.6438
# Epoch 83/100
# 15/15 [==============================] - 7s 466ms/step - loss: 2.6616e-04 - accuracy: 1.0000 - val_loss: 1.3611 - val_accuracy: 0.6438
# Epoch 84/100
# 15/15 [==============================] - 7s 466ms/step - loss: 2.4514e-04 - accuracy: 1.0000 - val_loss: 1.3547 - val_accuracy: 0.6567
# Epoch 85/100
# 15/15 [==============================] - 7s 469ms/step - loss: 2.4993e-04 - accuracy: 1.0000 - val_loss: 1.3602 - val_accuracy: 0.6481
# Epoch 86/100
# 15/15 [==============================] - 7s 468ms/step - loss: 3.0139e-04 - accuracy: 1.0000 - val_loss: 1.3683 - val_accuracy: 0.6481
# Epoch 87/100
# 15/15 [==============================] - 7s 466ms/step - loss: 2.8347e-04 - accuracy: 1.0000 - val_loss: 1.3711 - val_accuracy: 0.6438
# Epoch 88/100
# 15/15 [==============================] - 7s 466ms/step - loss: 2.6525e-04 - accuracy: 1.0000 - val_loss: 1.3551 - val_accuracy: 0.6609
# Epoch 89/100
# 15/15 [==============================] - 7s 466ms/step - loss: 2.4874e-04 - accuracy: 1.0000 - val_loss: 1.3680 - val_accuracy: 0.6524
# Epoch 90/100
# 15/15 [==============================] - 7s 466ms/step - loss: 2.0693e-04 - accuracy: 1.0000 - val_loss: 1.3749 - val_accuracy: 0.6438
# Epoch 91/100
# 15/15 [==============================] - 7s 466ms/step - loss: 2.2049e-04 - accuracy: 1.0000 - val_loss: 1.3775 - val_accuracy: 0.6567
# Epoch 92/100
# 15/15 [==============================] - 7s 465ms/step - loss: 2.3010e-04 - accuracy: 1.0000 - val_loss: 1.4125 - val_accuracy: 0.6395
# Epoch 93/100
# 15/15 [==============================] - 7s 466ms/step - loss: 2.1367e-04 - accuracy: 1.0000 - val_loss: 1.4135 - val_accuracy: 0.6481
# Epoch 94/100
# 15/15 [==============================] - 7s 467ms/step - loss: 1.8867e-04 - accuracy: 1.0000 - val_loss: 1.4093 - val_accuracy: 0.6481
# Epoch 95/100
# 15/15 [==============================] - 7s 469ms/step - loss: 2.3944e-04 - accuracy: 1.0000 - val_loss: 1.4143 - val_accuracy: 0.6395
# Epoch 96/100
# 15/15 [==============================] - 7s 465ms/step - loss: 1.8929e-04 - accuracy: 1.0000 - val_loss: 1.3834 - val_accuracy: 0.6524
# Epoch 97/100
# 15/15 [==============================] - 7s 465ms/step - loss: 2.2251e-04 - accuracy: 1.0000 - val_loss: 1.3726 - val_accuracy: 0.6438
# Epoch 98/100
# 15/15 [==============================] - 7s 472ms/step - loss: 1.9389e-04 - accuracy: 1.0000 - val_loss: 1.5402 - val_accuracy: 0.6395
# Epoch 99/100
# 15/15 [==============================] - 7s 466ms/step - loss: 2.4242e-04 - accuracy: 1.0000 - val_loss: 1.4929 - val_accuracy: 0.6052
# Epoch 100/100
# 15/15 [==============================] - 7s 462ms/step - loss: 1.8480e-04 - accuracy: 1.0000 - val_loss: 1.4296 - val_accuracy: 0.6180

# %% [markdown]
# #### Die Genauigkeit

# %%
loss, acc = model.evaluate(images, labels)
print("Train, accuracy: {:5.2f}%".format(100*acc))
# Out:
# 37/37 [==============================] - 2s 44ms/step - loss: 0.2870 - accuracy: 0.9233
# Train, accuracy: 92.33%

# %% [markdown]
# #### Die Metriken

# %%
y_pred_train = model.predict(images, batch_size=64, verbose=1)
y_pred_b = np.argmax(y_pred_train, axis=1)

print(classification_report(labels, y_pred_b))

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(confusion_matrix(labels, y_pred_b), classes=class_names)
plt.show()
# Out:
# 19/19 [==============================] - 2s 79ms/step
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95       154
#            1       0.93      0.89      0.91        80
#            2       0.89      0.97      0.93       149
#            3       0.95      0.88      0.91       157
#            4       0.88      0.86      0.87       154
#            5       0.90      0.96      0.93       158
#            6       0.93      0.92      0.92       154
#            7       0.95      0.95      0.95       155
#
#     accuracy                           0.92      1161
#    macro avg       0.92      0.92      0.92      1161
# weighted avg       0.92      0.92      0.92      1161
#
# Confusion matrix, without normalization

# %% [markdown]
# #### Visualisierung

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'valid'], loc='upper left')
plt.show()

# %%
pd.DataFrame(history.history).plot(figsize=(8, 5))
plt.grid(True)
plt.ylabel('accuracy/loss')
plt.xlabel('epoch')
plt.gca().set_ylim(0, 3.5)
plt.show()

# %% [markdown]
# ## Save Modell<a class="anchor" id="#savemodell"></a>

# %%
model.save_weights("kr_model.h5")

# %% [markdown]
# ## Test Modell<a class="anchor" id="#testmodell"></a>

# %%
PATH_RAVDESS_TEST = PATH_TO_RAVDESS/"test"
bs_test = 1440

# %%
ravdess_test = loader(PATH_RAVDESS_TEST)
ravdess_test_loader = torch.utils.data.DataLoader(ravdess_test,bs_test, shuffle=True)
images_test, labels_test = next(iter(ravdess_test_loader))

# %%
labels_test.shape
# Out:
# torch.Size([279])

# %%
images_test = (tf.cast(images_test, tf.float32) / 255).numpy()
labels_test = labels_test.numpy()

# %%
model_test = build_model()
model_test.load_weights('kr_model.h5')

# %% [markdown]
# ### Die Ganauigkeit<a class="anchor" id="#ganauigkeit"></a>

# %%
loss, acc = model_test.evaluate(images_test, labels_test)
print('Restored model, accuracy: {:5.2f}%'.format(100 * acc))
# Out:
# 9/9 [==============================] - 1s 42ms/step - loss: 1.7169 - accuracy: 0.6562
# Restored model, accuracy: 67.03%

# %% [markdown]
# ### Die Metriken<a class="anchor" id="#metriken"></a>

# %%
y_pred = model_test.predict(images_test, batch_size=64, verbose=1)
y_pred_bool = np.argmax(y_pred, axis=1)

print(classification_report(labels_test, y_pred_bool))

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(confusion_matrix(labels_test, y_pred_bool), classes=class_names)
plt.show()
# Out:
# 5/5 [==============================] - 0s 63ms/step
#               precision    recall  f1-score   support
#
#            0       0.71      0.58      0.64        38
#            1       0.92      0.69      0.79        16
#            2       0.83      0.93      0.88        43
#            3       0.47      0.43      0.45        35
#            4       0.88      0.39      0.55        38
#            5       0.56      0.85      0.67        34
#            6       0.59      0.68      0.63        38
#            7       0.67      0.78      0.72        37
#
#     accuracy                           0.67       279
#    macro avg       0.70      0.67      0.67       279
# weighted avg       0.69      0.67      0.66       279
#
# Confusion matrix, without normalization

# %%
model_test.save_weights("kr_model_prod.h5")
